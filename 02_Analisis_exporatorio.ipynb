# %% [markdown]
# # Analisis exploratorio del dataset

# %% [markdown]
# #### Indice de la notebook
# - Paso 1: Exploración de los datos.
# - Paso 2: Limpieza y preparación de los datos.
# - Paso 3: Análisis estadístico.
# - Paso 4: Desarrollo del análisis y obtención de insights.
# - Paso 5: Visualización y presentación de resultados.

# %%
# Library
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np
import scipy.stats
from sklearn.metrics import mean_squared_error
from math import sqrt
import os
from os import listdir
from datetime import datetime
import pandas as pd
from matplotlib.dates import DateFormatter
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
from sklearn.linear_model import LinearRegression
import seaborn as sn
import plotly.express as px

print("librerias ok")
# Out:
# librerias ok

# %%
# Se descarga el link de
# El link se saca de lo que me dice kaggle antes
df_test = pd.read_csv("C:/Users/Josefina Urquiza/.cache/kagglehub/competitions/titanic/Test.csv")
df_train = pd.read_csv("C:/Users/Josefina Urquiza/.cache/kagglehub/competitions/titanic/Train.csv")
#Unimos los dos dataset
df_concat = pd.concat([df_train, df_test], ignore_index=True)
#Verificamos
print(f"Hay {len(df_test)} registros en test")
print(f"Hay {len(df_train)} registros en train")
print(f"Hay {len(df_concat)} registros en total")

# Objetivo del proyecto: Predecir si sobrevivieron o no
#Hacemos una copia del df para no trabajar sobre la original
df = df_concat.copy()
df.columns
# Out:
# Hay 418 registros en test
# Hay 891 registros en train
# Hay 1309 registros en total
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
#Lo visualizamos
display(df.head())
# Out:
#                Event_Name     Pathogen_Name Pathogen_Type  Start_Year  \
# 0             Black Death   Yersinia pestis      Bacteria        1347
# 1     Plague of Justinian   Yersinia pestis      Bacteria         541
# 2         Antonine Plague  Smallpox/Measles         Virus         165
# 3  Second Pandemic Plague   Yersinia pestis      Bacteria        1361
# 4       Sweating Sickness           Unknown       Unknown        1485
#
#    End_Year  Duration_Years Origin_Region Geographic_Spread  \
# 0      1353               6  Central Asia            Global
# 1       549               8         Egypt       Continental
# 2       180              15     Near East       Continental
# 3      1363               2        Europe       Continental
# 4      1551              66       England          Regional
#
#    Continents_Affected  Estimated_Cases  ...  Case_Fatality_Rate_Pct  \
# 0                    6        200000000  ...                    37.5
# 1                    4         50000000  ...                    50.0
# 2                    3         10000000  ...                    50.0
# 3                    2         30000000  ...                    40.0
# 4                    1           300000  ...                    16.7
#
#    Primary_Transmission Containment_Method Economic_Impact_Billion_USD  \
# 0        Vector/Contact    Natural Decline                         500
# 1                Vector    Natural Decline                         300
# 2               Contact    Natural Decline                         200
# 3                Vector    Natural Decline                         100
# 4               Unknown    Natural Decline                          10
#
#    Medical_Breakthrough       Era WHO_Classification Mortality_Scale  \
# 0                  True  Medieval           Pandemic    Catastrophic
# 1                 False   Ancient           Pandemic    Catastrophic
# 2                 False   Ancient           Pandemic            High
# 3                 False  Medieval           Pandemic    Catastrophic
# 4                 False  Medieval           Epidemic             Low
#
#   Spread_Score       Century
# 0        22.50  14th Century
# 1        20.00   6th Century
# 2        15.00   2th Century
# 3         8.00  14th Century
# 4         1.67  15th Century
#
# [5 rows x 21 columns]

# %% [markdown]
# # Clase n° 2 del curso de ML
# ### Modulos y datos

# %% [markdown]
# Objetivo de la clase
# 1. repaso de herramientss (Pandas, Matplotlib, Seaborn y Ploty)
# 2. Analisis exploratorio: tecnicas de EDA
# 3. Limpieza de datos: Preparacion de datos para analisis efectivos
# 4. Consolidacion: integracion de multiples fuentes de manera coherente
#
#
# Partimos del dataset de la clase anterior
